# %%
#imports 
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
#reading in dataset train 
df = pd.read_csv('./datasets/train.csv')
df_test = pd.read_csv('datasets/test.csv')

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# my first run was good enough to get me into 3rd (for now), but it was over fit.  This attemp will try to fix that

# %% [markdown]
# Creating Function for EDA to make future me happy, i am keeping this the same for this run

# %%
#first lets create the function and some dummies 
def eda_function (df): 
    # replacing NAN in lot frontage with mean to reduce outlyers and still give a data point 
    df['Lot Frontage'].fillna(value=(df['Lot Frontage'].mean()), inplace = True)
    
    # replacing NAN in garage year with mean to reduce outlyers and still give a data point 
    df['Garage Yr Blt'].fillna(value=(df['Garage Yr Blt'].mean()), inplace = True)
    
    #replacing mason area with 0 as it is likely to be the case and it will not create an outlyer
    df['Mas Vnr Area'].fillna(value=(df['Mas Vnr Area'].mean()), inplace = True)

    #making catagories into dummies 
    df = pd.get_dummies(df, columns =['MS SubClass', 'MS Zoning',
       'Street', 'Alley', 'Lot Shape', 'Land Contour',
       'Utilities', 'Lot Config', 'Land Slope', 'Neighborhood',
       'Condition 1', 'Condition 2', 'Bldg Type', 'House Style',
       'Overall Qual', 'Overall Cond',
       'Roof Style', 'Roof Matl', 'Exterior 1st', 'Exterior 2nd',
       'Mas Vnr Type', 'Exter Qual', 'Exter Cond',
       'Foundation', 'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure',
       'BsmtFin Type 1', 'BsmtFin Type 2', 'Heating', 'Heating QC',
       'Central Air', 'Electrical','Kitchen Qual', 'Functional', 'Fireplace Qu', 'Garage Type',
       'Garage Finish', 'Garage Qual',
       'Garage Cond', 'Paved Drive',
       'Pool QC', 'Fence', 'Misc Feature', 'Sale Type'])
    #replacing all other NAs with zero  https://sparkbyexamples.com/pandas/pandas-replace-nan-values-by-zero-in-a-column/#:~:text=Replace%20NaN%20Values%20with%20Zero%20on%20pandas%20DataFrame,but%20returns%20a%20new%20DataFrame.
    df = df.fillna(0) 
    
    return df

# %% [markdown]
# sending info thorugh the function

# %%
df_test = eda_function(df_test)

# %%
df = eda_function(df)

# %% [markdown]
# dropping columns that are not in both sets

# %%
#finding those values  https://www.askpython.com/python/list/difference-between-two-lists-unique-entries#:~:text=In%20Python%2C%20to%20find%20the,unique%20entries%20from%20both%20lists.
list(set(df.columns.values) - set(df_test.columns.values))
# Out:
# ['Exterior 1st_CBlock',
#  'Condition 2_RRNn',
#  'Condition 2_RRAe',
#  'Heating_Wall',
#  'Misc Feature_Elev',
#  'Heating QC_Po',
#  'Roof Matl_ClyTile',
#  'Neighborhood_Landmrk',
#  'Bsmt Cond_Ex',
#  'Misc Feature_TenC',
#  'Pool QC_Fa',
#  'Electrical_Mix',
#  'Utilities_NoSeWa',
#  'Exterior 1st_Stone',
#  'Garage Qual_Ex',
#  'Exterior 2nd_Stone',
#  'Functional_Sev',
#  'MS SubClass_150',
#  'Condition 2_PosN',
#  'Heating_OthW',
#  'Pool QC_Gd',
#  'Condition 2_RRAn',
#  'Neighborhood_GrnHill',
#  'MS Zoning_A (agr)',
#  'SalePrice',
#  'Condition 2_Artery',
#  'Bsmt Cond_Po',
#  'Exterior 1st_ImStucc',
#  'Roof Matl_Membran',
#  'Overall Qual_1',
#  'Functional_Sal']

# %%
df_test = df_test.drop(columns = ['Kitchen Qual_Po',
 'Roof Matl_Metal',
 'Exterior 2nd_Other',
 'Exterior 2nd_PreCast',
 'Roof Matl_Roll',
 'Sale Type_VWD',
 'Mas Vnr Type_CBlock',
 'Heating_Floor',
 'Exterior 1st_PreCast',
                                 "PID"])

# %%
df =df.drop(columns = ['Bsmt Cond_Ex',
 'Misc Feature_Elev',
 'MS Zoning_A (agr)',
 'PID',
                       'Garage Qual_Ex',
 'Neighborhood_Landmrk',
 'Misc Feature_TenC',
 'Utilities_NoSeWa',
 'Neighborhood_GrnHill',
 'Exterior 1st_ImStucc',
 'Condition 2_RRAe',
 'Roof Matl_Membran',
 'Heating_Wall',
 'Electrical_Mix',
 'Condition 2_PosN',
 'Pool QC_Gd',
 'Condition 2_Artery',
 'Heating QC_Po',
 'Functional_Sal',
 'Condition 2_RRAn',
 'Exterior 1st_Stone',
 'Bsmt Cond_Po',
 'MS SubClass_150',
 'Exterior 1st_CBlock',
 'Pool QC_Fa',
 'Functional_Sev',
 'Heating_OthW',
 'Exterior 2nd_Stone',
 'Roof Matl_ClyTile',
 'Condition 2_RRNn',
 'Overall Qual_1'])

# %% [markdown]
# ## Removing Outlyers

# %%
df['SalePrice'].nsmallest(n=10)
# Out:
# 1628    12789
# 183     13100
# 1309    34900
# 1292    35000
# 1518    35311
# 1564    37900
# 1428    39300
# 408     40000
# 103     44000
# 1089    45000
# Name: SalePrice, dtype: int64

# %%
#there seems to be a few very small sale prices, we will remove those 
df.drop(df[df['SalePrice'] <40_000].index, inplace=True)

# %%
df['SalePrice'].nlargest(n=10)
# Out:
# 1671    611657
# 1964    591587
# 1692    584500
# 1796    582933
# 151     556581
# 1164    555000
# 623     552000
# 138     545224
# 823     538000
# 1592    535000
# Name: SalePrice, dtype: int64

# %%
df.drop(df[df['SalePrice'] >600_000].index, inplace=True)

# %% [markdown]
# Correlation.  I am going to look at corr and take out the values in the middle

# %%
corr = (df.corr()[['SalePrice']].sort_values(by = "SalePrice", ascending = False))
corr = corr[97:197].index
corr = corr.drop('Id')

# %%
df =df.drop(columns = corr)

# %%
df_test = df_test.drop(columns = corr)

# %% [markdown]
# Seeing what corr is left with a heatmap

# %%
df.corr()[['SalePrice']].sort_values(by=['SalePrice'], ascending=False)
# Out:
#                       SalePrice
# SalePrice              1.000000
# Gr Liv Area            0.695304
# Garage Area            0.650774
# Garage Cars            0.646917
# Total Bsmt SF          0.623330
# 1st Flr SF             0.612016
# Bsmt Qual_Ex           0.582279
# Year Built             0.569013
# Year Remod/Add         0.546648
# Kitchen Qual_Ex        0.545391
# Full Bath              0.536369
# Foundation_PConc       0.530047
# Garage Yr Blt          0.514768
# Mas Vnr Area           0.504217
# TotRms AbvGrd          0.495211
# Exter Qual_Ex          0.483663
# Fireplaces             0.467371
# BsmtFin Type 1_GLQ     0.459637
# Overall Qual_9         0.459117
# Exter Qual_Gd          0.453779
# Heating QC_Ex          0.449729
# Neighborhood_NridgHt   0.448684
# Overall Qual_8         0.429536
# Garage Finish_Fin      0.418876
# BsmtFin SF 1           0.412827
# Fireplace Qu_Gd        0.385282
# Overall Cond_5         0.369810
# Bsmt Exposure_Gd       0.367903
# MS SubClass_60         0.360473
# Garage Type_Attchd     0.355521
# Sale Type_New          0.354430
# Open Porch SF          0.345748
# Exterior 1st_VinylSd   0.343049
# Exterior 2nd_VinylSd   0.340697
# Wood Deck SF           0.328190
# Lot Frontage           0.325844
# Overall Qual_10        0.322609
# Kitchen Qual_Gd        0.310407
# Mas Vnr Type_Stone     0.299139
# Lot Area               0.298081
# Paved Drive_Y          0.281688
# Half Bath              0.281231
# Bsmt Full Bath         0.279362
# Neighborhood_NoRidge   0.267891
# Lot Shape_IR1          0.267650
# Roof Style_Hip         0.262826
# Central Air_Y          0.262694
# Mas Vnr Type_BrkFace   0.261830
# Neighborhood_StoneBr   0.261382
# Garage Cond_TA         0.261095
# 2nd Flr SF             0.251996
# Electrical_SBrkr       0.245774
# Garage Qual_TA         0.239250
# Fireplace Qu_Ex        0.230511
# Bsmt Qual_Gd           0.229319
# MS Zoning_RL           0.227232
# Garage Type_BuiltIn    0.223386
# Land Contour_HLS       0.204728
# House Style_2Story     0.203852
# Bsmt Unf SF            0.194712
# Garage Finish_RFn      0.187341
# Exterior 1st_CemntBd   0.164080
# Lot Config_CulDSac     0.160506
# Exterior 2nd_CmentBd   0.153319
# Neighborhood_Somerst   0.151034
# Fireplace Qu_TA        0.149301
# Overall Qual_7         0.145051
# Screen Porch           0.136561
# Bedroom AbvGr          0.131940
# Bsmt Exposure_Av       0.129826
# Functional_Typ         0.116422
# Bsmt Cond_Gd           0.115950
# Exter Cond_TA          0.115703
# Lot Shape_IR2          0.111660
# Condition 1_Norm       0.111592
# BsmtFin Type 2_Unf     0.110610
# Neighborhood_Timber    0.109903
# Condition 1_PosN       0.108611
# Bldg Type_1Fam         0.108413
# MS Zoning_FV           0.106630
# Condition 2_PosA       0.102796
# MS SubClass_120        0.102409
# Roof Matl_WdShngl      0.100216
# Garage Qual_Gd         0.098389
# Bsmt Cond_TA           0.086685
# Neighborhood_Veenker   0.084531
# Neighborhood_CollgCr   0.083301
# Heating_GasA           0.082902
# MS SubClass_20         0.073487
# Land Slope_Mod         0.073087
# Condition 1_PosA       0.072078
# Street_Pave            0.071194
# Bldg Type_TwnhsE       0.063066
# Neighborhood_Crawfor   0.059128
# BsmtFin Type 2_GLQ     0.054318
# Neighborhood_ClearCr   0.053257
# 3Ssn Porch             0.049439
# Id                    -0.045771
# Exterior 2nd_Wd Shng  -0.062564
# House Style_SFoyer    -0.065506
# Overall Cond_2        -0.067139
# Fireplace Qu_Po       -0.067377
# MS SubClass_180       -0.067852
# House Style_1.5Unf    -0.068133
# Overall Cond_1        -0.069268
# Roof Matl_CompShg     -0.070165
# Functional_Maj2       -0.071001
# Street_Grvl           -0.071194
# Land Slope_Gtl        -0.073209
# Garage Type_CarPort   -0.073370
# Electrical_FuseP      -0.073762
# Overall Cond_8        -0.075109
# Neighborhood_SWISU    -0.075759
# Lot Config_Inside     -0.077732
# MS SubClass_70        -0.077745
# Overall Qual_2        -0.082687
# BsmtFin Type 1_LwQ    -0.083279
# BsmtFin Type 1_ALQ    -0.090420
# Land Contour_Lvl      -0.092414
# Paved Drive_P         -0.092608
# Fence_GdWo            -0.094202
# Neighborhood_BrDale   -0.097180
# Exterior 2nd_AsbShng  -0.099137
# Land Contour_Bnk      -0.100253
# Exterior 2nd_HdBoard  -0.105010
# MS SubClass_90        -0.105888
# Bldg Type_Duplex      -0.105888
# Foundation_Slab       -0.109377
# Exterior 1st_AsbShng  -0.109783
# Sale Type_COD         -0.109840
# MS SubClass_190       -0.111484
# Condition 1_Feedr     -0.113215
# Bldg Type_2fmCon      -0.113684
# Neighborhood_MeadowV  -0.113746
# MS Zoning_C (all)     -0.115735
# Bldg Type_Twnhs       -0.116264
# Exterior 1st_HdBoard  -0.117140
# MS SubClass_160       -0.117377
# Heating QC_Gd         -0.118195
# Exter Qual_Fa         -0.120917
# Electrical_FuseF      -0.121390
# BsmtFin Type 1_Unf    -0.122009
# Overall Cond_3        -0.122734
# Condition 1_Artery    -0.127603
# Kitchen AbvGr         -0.128054
# BsmtFin Type 1_BLQ    -0.129219
# Overall Cond_7        -0.130540
# Neighborhood_BrkSide  -0.133683
# Enclosed Porch        -0.134639
# Garage Cond_Fa        -0.135660
# Neighborhood_Sawyer   -0.136516
# Overall Qual_6        -0.137691
# Exterior 2nd_MetalSd  -0.138580
# Bsmt Cond_Fa          -0.141384
# Heating QC_Fa         -0.143114
# Kitchen Qual_Fa       -0.148023
# Exter Cond_Fa         -0.149213
# Overall Qual_3        -0.149239
# Exterior 1st_MetalSd  -0.149364
# BsmtFin Type 1_Rec    -0.150416
# Fence_MnPrv           -0.153794
# Alley_Grvl            -0.158622
# Garage Qual_Fa        -0.158856
# Bsmt Qual_Fa          -0.159726
# Overall Cond_4        -0.163179
# Exterior 2nd_Wd Sdng  -0.174330
# Neighborhood_Edwards  -0.176748
# Neighborhood_IDOTRR   -0.180774
# MS SubClass_50        -0.183587
# Neighborhood_NAmes    -0.192003
# Overall Cond_6        -0.193356
# Exterior 1st_Wd Sdng  -0.193538
# Electrical_FuseA      -0.195812
# House Style_1.5Fin    -0.197450
# Neighborhood_OldTown  -0.206586
# Sale Type_WD          -0.210206
# Foundation_BrkTil     -0.226774
# MS SubClass_30        -0.243498
# Roof Style_Gable      -0.246780
# Central Air_N         -0.262694
# Paved Drive_N         -0.264600
# Overall Qual_4        -0.272474
# MS Zoning_RM          -0.283211
# Bsmt Exposure_No      -0.292176
# Lot Shape_Reg         -0.301167
# Heating QC_TA         -0.342899
# Foundation_CBlock     -0.362169
# Overall Qual_5        -0.367703
# Garage Type_Detchd    -0.372524
# Mas Vnr Type_None     -0.420852
# Garage Finish_Unf     -0.434033
# Bsmt Qual_TA          -0.459299
# Kitchen Qual_TA       -0.543188
# Exter Qual_TA         -0.604278

# %% [markdown]
# fitting the model

# %%
X = df.drop(columns=['SalePrice'])
y = df['SalePrice']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=2023)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_train, y_train)
# Out:
# 0.9085961655896564

# %%
lr.score(X_test, y_test)
# Out:
# 0.8935855208809411

# %%
lr = LinearRegression()
lr.fit(X, y)
# Out:
# LinearRegression()

# %%
df_test['SalePrice'] = lr.predict(df_test)

# %%
y_pred = lr.predict(X_train)
resids = y_train - y_pred

# %%
submission = df_test[['Id', 'SalePrice']]

# %%
submission.set_index('Id', inplace =True) 
submission
# Out:
#           SalePrice
# Id
# 2658  167353.612121
# 2718  148721.976464
# 2414  222345.635153
# 1989  109662.437891
# 625   183848.428401
# 333    87723.403911
# 1327  108550.831349
# 858   161762.832669
# 95    174832.354247
# 1568  167079.006564
# 2482  146123.467356
# 1364  119583.521488
# 2584  141356.320113
# 818   289141.871381
# 2673  141248.946155
# 2089  127257.814339
# 1297  137838.964692
# 790   116254.894902
# 2616  204098.132514
# 720   172538.989369
# 222   158917.290726
# 557   124294.694342
# 1148  180131.341078
# 2766  159821.880720
# 534   168351.890663
# 1452  125831.865656
# 630   129272.222068
# 2648  119829.495660
# 125   161778.423261
# 1904   73323.536578
# 1670  106105.877897
# 756    96035.324801
# 717   229429.687253
# 1032  153327.991274
# 852   213897.141242
# 1731  169654.350648
# 2639  119176.307913
# 2071  103973.813588
# 1267  153082.647516
# 1851  189650.947928
# 567   162154.016588
# 2439  202015.659761
# 1898  153487.084181
# 647   165543.277038
# 2256  200636.616536
# 979    94260.332333
# 1444  212972.379860
# 2485  138829.396926
# 157   143754.834211
# 88    118784.800771
# 2003  100028.522596
# 186   217071.626931
# 1425  235147.766342
# 2695  128364.072716
# 738   114701.530427
# 395   162205.518436
# 1353  169534.113464
# 1878  135783.867795
# 390   169123.691590
# 1456  225572.038328
# 1103  302494.557509
# 1387  111162.105806
# 2070  155217.741151
# 1199  162492.745700
# 2479  174997.646094
# 501   336757.816649
# 2362   94448.844097
# 1718  203720.538658
# 2188   95426.269542
# 1483  156751.551704
# 2557   99931.265357
# 437   323713.133914
# 2224  201608.550091
# 1628  175069.625864
# 397   145619.817451
# 587   186498.040202
# 971   138277.039771
# 2611  130292.239714
# 1887  101801.877915
# 2399  384563.685161
# 2148  191897.633014
# 304   119523.656379
# 1997  125902.466324
# 2817  107690.428415
# 1431  223984.870426
# 427   336757.845343
# 263   140159.093008
# 598   172186.650823
# 2895  204604.845891
# 687   118994.892789
# 1822  129232.762839
# 2191  107082.703772
# 179    97451.633109
# 1009  227057.514338
# 2010  149096.154810
# 1991  132001.471874
# 1411  202801.796829
# 1721  238395.682424
# 1144  193588.102170
# 593   220739.556247
# 575   314922.801595
# 1249  176908.161039
# 1604  132312.530586
# 1064  448509.348527
# 1923  143037.785888
# 1988  121857.243374
# 2325  168936.674254
# 114   192345.863024
# 2700  136317.115943
# 217   104557.067013
# 343   174005.837815
# 386   222864.356346
# 2005  130442.028747
# 2908  138573.977606
# 1814  189457.418010
# 2446  452814.414409
# 208   124360.541288
# 1679  124686.875843
# 822   346848.567542
# 6     189325.236894
# 1781  368138.919569
# 2397  303490.236674
# 2340  332909.031399
# 1618  182113.788578
# 2843  135287.244344
# 1061  375845.122703
# 2786  120236.183473
# 1935  140876.145002
# 1341  127759.546702
# 521   281210.107782
# 2136  141969.662972
# 996   215420.713411
# 227   144956.747414
# 135   177050.271643
# 1167  167483.246887
# 294   221590.619417
# 1776  202505.738281
# 540   156754.876454
# 1717  212660.952893
# 2303  129873.078250
